# %%
import warnings
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df_movies = pd.read_csv('IMDB.csv')

df_movies.head(10)
# Out:
#                         Title  title_year     budget      Gross  \
# 0                  La La Land        2016   30000000  151101803
# 1                    Zootopia        2016  150000000  341268248
# 2                        Lion        2016   12000000   51738905
# 3                     Arrival        2016   47000000  100546139
# 4       Manchester by the Sea        2016    9000000   47695371
# 5          Hell or High Water        2016   12000000   27007844
# 6              Doctor Strange        2016  165000000  232641920
# 7                     Tangled        2010  260000000  200807262
# 8       The Dark Knight Rises        2012  250000000  448130642
# 9  Captain America: Civil War        2016  250000000  407197282
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# ...

# %%
df_movies.shape
# Out:
# (100, 62)

# %%
df_movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
#Read specific column
df_new = df_movies[["Title","genre_1","genre_2","genre_3"]]

df_new.head()
# Out:
#                    Title    genre_1    genre_2 genre_3
# 0             La La Land     Comedy      Drama   Music
# 1               Zootopia  Animation  Adventure  Comedy
# 2                   Lion  Biography      Drama     NaN
# 3                Arrival      Drama    Mystery  Sci-Fi
# 4  Manchester by the Sea      Drama        NaN     NaN

# %%
#Read specific rows
df_movies.loc[10:15] #prints row from 10 to 15
# Out:
#                                   Title  title_year     budget      Gross  \
# 10  The Hobbit: The Desolation of Smaug        2013  225000000  258355354
# 11                         The Avengers        2012  220000000  623279547
# 12                          Toy Story 3        2010  200000000  414984497
# 13                              Skyfall        2012  200000000  304360277
# 14           X-Men: Days of Future Past        2014  200000000  233914986
# 15              Star Trek Into Darkness        2013  190000000  228756232
#
#             actor_1_name       actor_2_name        actor_3_name  \
# 10          Aidan Turner         Adam Brown       James Nesbitt
# 11       Chris Hemsworth  Robert Downey Jr.  Scarlett Johansson
# 12             Tom Hanks  John Ratzenberger         Don Rickles
# 13         Albert Finney      Helen McCrory        Rory Kinnear
# 14     Jennifer Lawrence     Peter Dinklage        Hugh Jackman
# ...

# %%
#mean value of facebook likes of actor1
df_movies["actor_1_facebook_likes"].mean()
# Out:
# 13407.27

# %%
df_movies["actor_2_facebook_likes"].mean()
# Out:
# 7377.30303030303

# %%
df_movies["actor_3_facebook_likes"].mean()
# Out:
# 3002.1530612244896

# %%
#creating dictionary and plotting graph
actor_likes = {a1:''}

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'
df_movies["budget"] = df_movies["budget"] / 1000000
df_movies["Gross"] = df_movies["Gross"] / 1000000
df_movies.head
# Out:
# <bound method NDFrame.head of                                            Title  title_year    budget  \
# 0                                     La La Land        2016  0.000030
# 1                                       Zootopia        2016  0.000150
# 2                                           Lion        2016  0.000012
# 3                                        Arrival        2016  0.000047
# 4                          Manchester by the Sea        2016  0.000009
# ..                                           ...         ...       ...
# 95                                      Whiplash        2014  0.000003
# 96                               Before Midnight        2013  0.000003
# 97    Star Wars: Episode VII - The Force Awakens        2015  0.000245
# 98  Harry Potter and the Deathly Hallows: Part I        2010  0.000150
# 99                       Tucker and Dale vs Evil        2010  0.000005
#
#            Gross              actor_1_name        actor_2_name  \
# ...

# %%
# Create the new column named 'profit' by subtracting the 'budget' column from the 'gross' column
df_movies["profit"] = df_movies["Gross"] - df_movies["budget"]

# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. Make sure to set the argument
#'ascending' to 'False'
df_movies.sort_values(by="profit",ascending=False)
# Out:
#                                          Title  title_year     budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
# 11                                The Avengers        2012  220000000
# 47                                    Deadpool        2016   58000000
# 32             The Hunger Games: Catching Fire        2013  130000000
# 12                                 Toy Story 3        2010  200000000
# ..                                         ...         ...        ...
# 46                 Scott Pilgrim vs. the World        2010   60000000
# 7                                      Tangled        2010  260000000
# 17                            Edge of Tomorrow        2014  178000000
# 39                           The Little Prince        2015   81200000
# 22                                        Hugo        2011  170000000
#
#         Gross         actor_1_name       actor_2_name           actor_3_name  \
# ...

# %%
#Plot profit vs budget
sns.scatterplot(data=df_movies,x="profit",y="budget")
plt.show()

# %%
#Find the movies with negative profit
df_movies[df_movies["profit"] < 0]
# Out:
#                           Title  title_year    budget         Gross  \
# 7                       Tangled        2010  0.000260  2.008073e-04
# 17             Edge of Tomorrow        2014  0.000178  1.001895e-04
# 22                         Hugo        2011  0.000170  7.382009e-05
# 28           X-Men: First Class        2011  0.000160  1.464054e-04
# 39            The Little Prince        2015  0.000081  1.339152e-06
# 46  Scott Pilgrim vs. the World        2010  0.000060  3.149427e-05
# 56                         Rush        2013  0.000038  2.690371e-05
# 66                      Warrior        2011  0.000025  1.365166e-05
# 82                      Flipped        2010  0.000014  1.752214e-06
# 89                        Amour        2012  0.000009  2.253770e-07
# 99      Tucker and Dale vs Evil        2010  0.000005  2.238380e-07
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 7          Brad Garrett        Donna Murphy             M.C. Gainey
# ...

# %%
# Change the scale of MetaCritic
df_movies["MetaCritic"] = df_movies["MetaCritic"] / 10
# Find the average ratings
df_movies["Avg_rating"] = (df_movies["MetaCritic"] + df_movies["IMDb_rating"]) / 2
df_movies.head()
#Sort in descending order of average rating
df_movies.sort_values(by="Avg_rating",ascending=False)
# Out:
#                                 Title  title_year    budget     Gross  \
# 27                          Inception        2010  0.000160  0.000293
# 26                       Interstellar        2014  0.000165  0.000188
# 95                           Whiplash        2014  0.000003  0.000013
# 35                   Django Unchained        2012  0.000100  0.000163
# 8               The Dark Knight Rises        2012  0.000250  0.000448
# ..                                ...         ...       ...       ...
# 16  The Hobbit: An Unexpected Journey        2012  0.000180  0.000303
# 52                      Lone Survivor        2013  0.000040  0.000125
# 71                     The Book Thief        2013  0.000019  0.000021
# 82                            Flipped        2010  0.000014  0.000002
# 88                         About Time        2013  0.000012  0.000015
#
#            actor_1_name       actor_2_name          actor_3_name  \
# ...

# %%
#Plot profit vs budget
sns.scatterplot(data=df_movies,x="title_year",y="Avg_rating")
plt.show()
